# %%
# 불과 비교 연산자 사용하기
True
False

# %%
# 비교 연산자의 판단 결과
3 > 1
# Out:
# True

# %%
# 숫자 같은지 비교
10 == 10
# Out:
# True

# %%
# 문자 같은지 비교
print("Python"=="Python")
print("Python"=="python")
print("Python"!="python") # 다르다는뜻
# Out:
# True
# False
# True

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
# 객체가 같은지 다른지 비교하기
print(1 == 1.0)
print( 1 is 1.0)
# Out:
# True
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_10988\3065008272.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print( 1 is 1.0)

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_10988\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
# 논리 연산자 사용하기
## And 연산자
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
## Or 연산자
print(True or False)
print(True or True)
print(False or False)
# Out:
# True
# True
# False

# %%
(not True) and False or not False
# Out:
# True

# %%
# 논리연산자와 비교연산자 사용
print(10 == 10 and 10 != 5)

print((10 > 5) or (10 < 3))

print(not 10 > 5)

print(not 1 is 1.0)
# Out:
# True
# True
# False
# True
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_10988\2460908801.py:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
kor, eng, math, sci = map(int,input().split())

kor >=90 and eng>80 and math >85, sci>= 80
# Out:
# (True, True)
