# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
if x == 10:
    print("x에 들어있는 숫자는")

print("10입니다")
# Out:
# x에 들어있는 숫자는
# 10입니다

# %%
# 중첩 if 조건문 사용하기
# x = 15
# x = 10
x = 20
if x >= 10:
    print("10이상입니다.")
    
    if x == 10:
        print("10입니다")

    if x == 20:
        print("20입니다.")
# Out:
# 10이상입니다.
# 20입니다.

# %%
x = int(input("숫자를 입력하세요:"))

if x == 10:
    print("10입니다")

if x == 20:
    print("20입니다")

# %%
가격 = int(input("가격을입력하세요:"))
쿠폰 = input("캐쉬쿠폰을 입력하세요:")

if 쿠폰 == 'Cash3000':
    print(f"가격은{가격-3000}입니다")


if 쿠폰 == 'Cash5000':
    print(f"가격은{가격-5000}입니다")
# Out:
# 가격은67000입니다
